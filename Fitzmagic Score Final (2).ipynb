# %%
import pandas as pd

# %%
nfldata = pd.read_csv('qb_games.csv')

# %%
nfldata.head()
# Out:
#     Rk                     NAME     Age      Date   Lg   Tm AWAY  Opp  \
# 0  1.0       Tom Brady\BradTo00  33.114  11/25/10  NFL  NWE    @  DET
# 1  2.0      Drew Brees\BreeDr00  30.319  11/30/09  NFL  NOR  NaN  NWE
# 2  3.0    Kirk Cousins\CousKi00  27.088  11/15/15  NFL  WAS  NaN  NOR
# 3  4.0      Nick Foles\FoleNi00  24.287   11/3/13  NFL  PHI    @  OAK
# 4  5.0  Robert Griffin\GrifRo01  22.280  11/18/12  NFL  WAS  NaN  PHI
#
#     Result    G# ...  Passing Cmp% Passing Yds  Passing TD  Passing Int  \
# 0  W 45-24  11.0 ...         77.78       341.0         4.0          0.0
# 1  W 38-17  11.0 ...         78.26       371.0         5.0          0.0
# 2  W 47-14   9.0 ...         80.00       324.0         4.0          0.0
# 3  W 49-20   9.0 ...         78.57       406.0         7.0          0.0
# 4   W 31-6  10.0 ...         93.33       200.0         4.0          0.0
#
#    Passing Rate  Passing Sk  Passing Yds2  Passing Y/A  Passing AY/A
# 0         158.3         1.0           3.0        12.63         15.59 NaN
# 1         158.3         1.0           4.0        16.13         20.48 NaN
# 2         158.3         3.0          23.0        12.96         16.16 NaN
# 3         158.3         1.0           1.0        14.50         19.50 NaN
# 4         158.3         2.0           8.0        13.33         18.67 NaN
#
# [5 rows x 24 columns]

# %%
rating_overall = nfldata.loc[:,"Passing Rate"]
names = nfldata.loc[:,"NAME"]

# %%
overall_stdev = rating_overall.std()

# %%
overall_mean = rating_overall.mean()

# %%
overall_mean
# Out:
# 86.60492957746477

# %%
print(overall_stdev)
# Out:
# 27.81704576350518

# %%
nfldata.describe()
# Out:
#                 Rk          Age           G#         Week  Passing Cmp  \
# count  5396.000000  5396.000000  5396.000000  5396.000000  5396.000000
# mean   2698.500000    28.662279     8.391030     8.968125    20.273721
# std    1557.835357     4.430381     4.655449     5.053642     6.602001
# min       1.000000    21.097000     1.000000     1.000000     1.000000
# 25%    1349.750000    25.134750     4.000000     4.000000    16.000000
# 50%    2698.500000    28.122000     8.000000     9.000000    20.000000
# 75%    4047.250000    32.042500    12.000000    13.000000    24.000000
# max    5396.000000    41.051000    16.000000    17.000000    44.000000
#
#        Passing Att  Passing Cmp%  Passing Yds   Passing TD  Passing Int  \
# count  5396.000000   5396.000000  5396.000000  5396.000000  5396.000000
# mean     32.838584     61.616775   233.485174     1.416049     0.866383
# std       9.382910     10.194728    82.798915     1.143541     0.965644
# min      10.000000      9.090000    -7.000000     0.000000     0.000000
# 25%      27.000000     55.170000   178.000000     1.000000     0.000000
# 50%      33.000000     61.760000   232.000000     1.000000     1.000000
# 75%      39.000000     68.750000   290.000000     2.000000     1.000000
# max      67.000000     94.740000   527.000000     7.000000     6.000000
#
#        Passing Rate   Passing Sk  Passing Yds2  Passing Y/A  Passing AY/A
# count   5396.000000  5396.000000   5396.000000  5396.000000   5396.000000  0.0
# mean      86.604930     2.157153     14.008154     7.152187      6.825673  NaN
# std       27.817046     1.655991     11.988561     1.949766      3.125267  NaN
# min        0.000000     0.000000      0.000000    -0.580000    -11.360000  NaN
# 25%       68.200000     1.000000      5.000000     5.840000      4.910000  NaN
# 50%       86.100000     2.000000     12.000000     7.000000      6.760000  NaN
# 75%      105.300000     3.000000     21.000000     8.300000      8.700000  NaN
# max      158.300000    11.000000     91.000000    17.300000     21.300000  NaN

# %%
allqbs = set(names)

# %%
stddev = nfldata.groupby('NAME')[['Passing Rate']].std()

# %%
avg = nfldata.groupby('NAME')[['Passing Rate']].mean()

# %%
combined = (stddev / overall_stdev) * (overall_mean / avg) * 100

# %%
fitzmagic_score = combined.sort_values(by=['Passing Rate'],ascending = False)

# %%
fitzmagic_score
# Out:
#                            Passing Rate
# NAME
# Todd Collins\CollTo00        383.967848
# Nathan Peterman\PeteNa00     284.395903
# David Carr\CarrDa00          215.679295
# Kevin Hogan\HogaKe00         204.729161
# Brian Brohm\BrohBr00         182.316476
# Curtis Painter\PainCu00      180.939236
# Luke McCown\McCoLu00         172.088776
# Max Hall\HallMa00            171.054090
# Brett Hundley\HundBr00       164.477051
# Brady Quinn\QuinBr00         162.938112
# Caleb Hanie\HaniCa00         161.532879
# Sam Darnold\DarnSa00         160.017436
# Damon Huard\HuarDa00         159.023307
# Byron Leftwich\LeftBy00      154.195045
# Brad Johnson\JohnBr00        153.527423
# Geno Smith\SmitGe00          150.081095
# JaMarcus Russell\RussJa00    146.171518
# Charlie Frye\FryeCh00        146.034795
# John Skelton\SkelJo00        145.805801
# Terrelle Pryor\PryoTe00      143.835891
# Derek Anderson\AndeDe00      141.759113
# Drew Stanton\StanDr00        140.398428
# Mark Brunell\BrunMa00        137.447490
# Daunte Culpepper\CulpDa00    137.073239
# Johnny Manziel\ManzJo00      136.163393
# Kellen Moore\MoorKe02        134.670487
# Jake Delhomme\DelhJa00       133.027540
# Tim Tebow\TeboTi00           125.554676
# Matt Leinart\LeinMa00        122.651990
# DeShone Kizer\KizeDe00       122.533253
# ...                                 ...
# Jacoby Brissett\BrisJa00      67.818922
# Tom Savage\SavaTo00           65.172513
# Dennis Dixon\DixoDe00         65.022895
# Stephen McGee\McGeSt00        64.073842
# Chad Pennington\PennCh01      63.936948
# Sage Rosenfels\RoseSa00       60.199528
# Chase Daniel\DaniCh00         59.377316
# John Beck\BeckJo00            54.460755
# Thaddeus Lewis\LewiTh01       52.983314
# A.J. Feeley\FeelA.00          42.067408
# A.J. McCarron\McCaA.00        40.189604
# Andrew Walter\WaltAn00         4.206668
# Alex Tanney\TannAl00                NaN
# Baker Mayfield\MayfBa00             NaN
# Billy Volek\VoleBi00                NaN
# Brian St. Pierre\St.PBr20           NaN
# Brooks Bollinger\BollBr00           NaN
# Cardale Jones\JoneCa01              NaN
# Chris Simms\SimmCh00                NaN
# Connor Cook\CookCo00                NaN
# Connor Shaw\ShawCo00                NaN
# David Fales\FaleDa00                NaN
# Greg McElroy\McElGr00               NaN
# Jim Sorgi\SorgJi00                  NaN
# Matt Simms\SimmMa00                 NaN
# Nate Sudfeld\SudfNa00               NaN
# Rusty Smith\SmitRu01                NaN
# Sean Mannion\MannSe00               NaN
# Todd Bouman\BoumTo00                NaN
# Tony Pike\PikeTo00                  NaN
#
# [173 rows x 1 columns]

# %%
type(fitzmagic_score)
# Out:
# pandas.core.frame.DataFrame

# %%
testdata = nfldata

# %%
cleandata = testdata.groupby("NAME").filter(lambda x: len(x) >= 10)

# %%
cleanstddev = cleandata.groupby('NAME')[['Passing Rate']].std()

# %%
cleanavg = cleandata.groupby('NAME')[['Passing Rate']].mean()

# %%
cleanavg
# Out:
#                              Passing Rate
# NAME
# Aaron Rodgers\RodgAa00         104.427972
# Alex Smith\SmitAl03             93.743200
# Andrew Luck\LuckAn00            88.121918
# Andy Dalton\DaltAn00            90.617117
# Austin Davis\DaviAu00           83.650000
# Ben Roethlisberger\RoetBe00     94.647260
# Blaine Gabbert\GabbBl00         71.806383
# Blake Bortles\BortBl00          81.141538
# Brady Quinn\QuinBr00            63.089474
# Brandon Weeden\WeedBr00         76.557143
# Brett Favre*\FavrBr00           89.148837
# Brett Hundley\HundBr00          70.350000
# Brian Hoyer\HoyeBr00            83.509091
# Brock Osweiler\OsweBr00         77.665517
# Bruce Gradkowski\GradBr00       70.946154
# Cam Newton\NewtCa00             87.436607
# Carson Palmer\PalmCa00          86.803333
# Carson Wentz\WentCa00           89.876667
# Case Keenum\KeenCa00            86.833333
# Chad Henne\HennCh01             75.989655
# Chad Pennington\PennCh01        95.078947
# Charlie Whitehurst\WhitCh02     77.993333
# Christian Ponder\PondCh00       74.772222
# Colin Kaepernick\KaepCo00       89.463793
# Colt McCoy\McCoCo00             82.451852
# Curtis Painter\PainCu00         55.845455
# Dak Prescott\PresDa01           96.485294
# Dan Orlovsky\OrloDa00           77.600000
# Daunte Culpepper\CulpDa00       59.558333
# David Garrard\GarrDa00          85.132609
# ...                                   ...
# Matthew Stafford\StafMa00       89.400781
# Michael Vick\VickMi00           86.804444
# Mike Glennon\GlenMi00           85.720833
# Mitch Trubisky\TrubMi00         79.378571
# Nick Foles\FoleNi00             87.204444
# Peyton Manning\MannPe00         99.232692
# Philip Rivers\RivePh00          98.580368
# Rex Grossman\GrosRe00           72.233333
# Robert Griffin\GrifRo01         88.357500
# Russell Wilson\WilsRu00         99.074747
# Ryan Fitzpatrick\FitzRy00       81.904098
# Ryan Lindley\LindRy00           56.950000
# Ryan Tannehill\TannRy00         88.736709
# Sam Bradford\BradSa00           85.195181
# Seneca Wallace\WallSe00         83.594737
# Shaun Hill\HillSh00             87.205556
# T.J. Yates\YateT.00             71.430769
# Tarvaris Jackson\JackTa00       84.460870
# Teddy Bridgewater\BridTe00      86.934483
# Terrelle Pryor\PryoTe00         72.310000
# Tim Tebow\TeboTi00              79.257143
# Tom Brady\BradTo00             101.415972
# Tom Savage\SavaTo00             70.930000
# Tony Romo\RomoTo00              98.997980
# Trent Edwards\EdwaTr01          76.573913
# Trevor Siemian\SiemTr00         81.773913
# Tyler Thigpen\ThigTy00          75.106250
# Tyrod Taylor\TaylTy00           89.748936
# Vince Young\YounVi00            83.581818
# Zach Mettenberger\MettZa00      74.636364
#
# [102 rows x 1 columns]

# %%
finalscore = (cleanstddev / overall_stdev) * (overall_mean / cleanavg) * 100

# %%
final_fitzmagic_score = finalscore.sort_values(by=['Passing Rate'],ascending = False)

# %%
final_fitzmagic_score.to_csv("output2.csv",index=True)
